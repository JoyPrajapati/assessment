# %%
import pandas as pd

# %%
banks = pd.read_csv("C:/Users/Dell/OneDrive/Desktop/TOPS/assessments/assessment/n,p,assess.csv")
banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %%
#head of dataset

banks.head(10)
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
banks.tail()
# Out:
#                              Bank Name        City  ST   CERT  \
# 548                 Superior Bank, FSB    Hinsdale  IL  32646
# 549                Malta National Bank       Malta  OH   6629
# 550    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 551  National State Bank of Metropolis  Metropolis  IL   3815
# 552                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date Updated Date
# 548                Superior Federal, FSB    27-Jul-01    19-Aug-14
# 549                    North Valley Bank     3-May-01    18-Nov-02
# 550  Southern New Hampshire Bank & Trust     2-Feb-01    18-Feb-03
# 551              Banterra Bank of Marion    14-Dec-00    17-Mar-05
# 552                   Bank of the Orient    13-Oct-00    17-Mar-05

# %%
banks.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
#

banks.describe()
# Out:
#                CERT
# count    553.000000
# mean   31729.652803
# std    16420.594894
# min       91.000000
# 25%    20340.000000
# 50%    32218.000000
# 75%    35372.000000
# max    58701.000000

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              553 non-null    object
#  1   City                   553 non-null    object
#  2   ST                     553 non-null    object
#  3   CERT                   553 non-null    int64
#  4   Acquiring Institution  553 non-null    object
#  5   Closing Date           553 non-null    object
#  6   Updated Date           553 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 30.4+ KB

# %%
#LIST OF STATES

x=banks['ST'].unique().tolist()
x
# Out:
# ['IL',
#  'WI',
#  'LA',
#  'UT',
#  'NJ',
#  'AR',
#  'GA',
#  'PA',
#  'TN',
#  'WA',
#  'CO',
#  'PR',
#  'FL',
#  'MN',
#  'CA',
#  'MD',
#  'OK',
#  'OH',
#  'SC',
#  'VA',
#  'ID',
#  'TX',
#  'CT',
#  'AZ',
#  'NV',
#  'NC',
#  'KY',
#  'MO',
#  'KS',
#  'AL',
#  'MI',
#  'IN',
#  'IA',
#  'NE',
#  'MS',
#  'NM',
#  'OR',
#  'NY',
#  'MA',
#  'SD',
#  'WY',
#  'WV',
#  'NH',
#  'HI']

# %%
#TOP 5 STATES WITH MOST FAILED BANKS

banks['ST'].value_counts().head(5)
# Out:
# ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# Name: count, dtype: int64

# %%
#TOP 5 acquiring institutions?

banks['Acquiring Institution'].value_counts().head(5)
# Out:
# Acquiring Institution
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Name: count, dtype: int64

# %%
fil_data=banks['Acquiring Institution']== 'State Bank of Texas'
fil_data.sum()
# Out:
# np.int64(3)

# %%
in_texas=banks['ST']=='TX'
in_texas.sum()
# Out:
# np.int64(12)

# %%
final=fil_data.sum()&in_texas.sum()
final
# Out:
# np.int64(0)

# %%
Y=banks[banks['ST']=='CA']

# %%
Y['City'].value_counts().idxmax()
# Out:
# 'Chicago'
